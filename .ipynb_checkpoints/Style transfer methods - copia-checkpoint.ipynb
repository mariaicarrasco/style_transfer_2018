# %% [markdown]
# # Style transfer Methods, A review

# %% [markdown]
# ### A Neural Algorithm of Artistic Style
# Source: https://harishnarayanan.org/writing/artistic-style-transfer/
#
# Using VGG16 (or 19) and a gramm matrix to solve an optimization problem

# %%
# Imports
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_size = 128
images_path = "E:/UdeC/S1 2018/ML/Style Transfer"
# Load a content image
content_image = Image.open(images_path+"/content_images/05.jpg").resize((image_size, image_size))
style_image = Image.open(images_path+"/style_images/09.jpg").resize((image_size, image_size))
content_image # Resize just to see it at a smaller size
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1F4CB8FE160>

# %%
# Transforming into numeric information
content_array = np.asarray(content_image, dtype='float32')
content_array = np.expand_dims(content_array, axis=0)
style_array = np.asarray(style_image, dtype='float32')
style_array = np.expand_dims(style_array, axis=0)

red_mean = 103.939
green_mean = 116.779
blue_mean = 123.68

content_array[:,:,:,0] -= red_mean
content_array[:,:,:,1] -= green_mean
content_array[:,:,:,2] -= blue_mean
content_array = content_array[:,:,:,::-1]
style_array[:,:,:,0] -= red_mean
style_array[:,:,:,1] -= green_mean
style_array[:,:,:,2] -= blue_mean
style_array = style_array[:,:,:,::-1]

print(content_array.shape, style_array.shape)
# Out:
# (1, 128, 128, 3) (1, 128, 128, 3)

# %%
#Defining our loss functions
def content_loss(content, combination):
    return tf.reduce_sum(tf.square(content-combination))

def gram_matrix(x): # Hay que entenderla bien
    features = tf.keras.backend.batch_flatten(tf.keras.backend.permute_dimensions(x, (2, 0, 1)))
    gram = tf.matmul(features, tf.transpose(features))
    return gram
def style_loss(style, combination): # Tambien
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    return tf.reduce_sum(tf.square(S - C)) / (4. * (channels ** 2) * (image_size ** 4))
def total_variation_loss(x):
    a = tf.square(x[:, :image_size-1, :image_size-1, :] - x[:, 1:, :image_size-1, :])
    b = tf.square(x[:, :image_size-1, :image_size-1, :] - x[:, :image_size-1, 1:, :])
    return tf.reduce_sum(tf.pow(a + b, 1.25))

# %%
# Start creating the main graph
content_node = tf.constant(content_array, name = "content_image", dtype=tf.float32)
style_node = tf.constant(style_array, name = "style_image", dtype=tf.float32)
combination_image = tf.Variable(tf.random_uniform(shape=[1,image_size, image_size,3], minval = -1, maxval= 1), dtype=tf.float32)
input_ten = tf.concat([content_node, style_node, combination_image], axis = 0)

# %%
# Importing the VGG16 pre-trained net to use it on the content loss
vgg = tf.keras.applications.VGG16(include_top = False, weights = "imagenet", input_tensor = input_ten)

# %%
layers = dict([(layer.name, layer.output) for layer in vgg.layers])
layers
# Out:
# {'block1_conv1': <tf.Tensor 'block1_conv1_2/Relu:0' shape=(3, 128, 128, 64) dtype=float32>,
#  'block1_conv2': <tf.Tensor 'block1_conv2_2/Relu:0' shape=(3, 128, 128, 64) dtype=float32>,
#  'block1_pool': <tf.Tensor 'block1_pool_2/MaxPool:0' shape=(3, 64, 64, 64) dtype=float32>,
#  'block2_conv1': <tf.Tensor 'block2_conv1_2/Relu:0' shape=(3, 64, 64, 128) dtype=float32>,
#  'block2_conv2': <tf.Tensor 'block2_conv2_2/Relu:0' shape=(3, 64, 64, 128) dtype=float32>,
#  'block2_pool': <tf.Tensor 'block2_pool_2/MaxPool:0' shape=(3, 32, 32, 128) dtype=float32>,
#  'block3_conv1': <tf.Tensor 'block3_conv1_2/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_conv2': <tf.Tensor 'block3_conv2_2/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_conv3': <tf.Tensor 'block3_conv3_2/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_pool': <tf.Tensor 'block3_pool_2/MaxPool:0' shape=(3, 16, 16, 256) dtype=float32>,
#  'block4_conv1': <tf.Tensor 'block4_conv1_2/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_conv2': <tf.Tensor 'block4_conv2_2/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_conv3': <tf.Tensor 'block4_conv3_2/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_pool': <tf.Tensor 'block4_pool_2/MaxPool:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv1': <tf.Tensor 'block5_conv1_2/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv2': <tf.Tensor 'block5_conv2_2/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv3': <tf.Tensor 'block5_conv3_2/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_pool': <tf.Tensor 'block5_pool_2/MaxPool:0' shape=(3, 4, 4, 512) dtype=float32>,
#  'input_3': <tf.Tensor 'concat_2:0' shape=(3, 128, 128, 3) dtype=float32>}

# %%
# Continue with the graph
content_weight = 0.025*20
style_weight = 5
total_variation_weight = 1

content_reference_layer = "block2_conv2"
style_reference_layers = ['block1_conv2', 'block2_conv2',
                  'block3_conv3', 'block4_conv3',
                  'block5_conv3']

loss = tf.Variable(0, name = "total_loss", dtype=tf.float32)

content_feature_layer = layers[content_reference_layer]
loss = loss + content_weight * content_loss(content_feature_layer[0,:,:,:], content_feature_layer[2,:,:,:])

for layer in style_reference_layers:
    style_feature_layers = layers[layer]
    loss = loss + (style_loss(style_feature_layers[1,:,:,:], style_feature_layers[2,:,:,:]))*style_weight/len(style_reference_layers)

loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    plt.subplot(1,4,1)
    plt.imshow(layers[content_reference_layer][0,:,:,40].eval())
    plt.subplot(1,4,2)
    plt.imshow(layers[content_reference_layer][2,:,:,40].eval())
    plt.subplot(1,4,3)
    plt.imshow(layers[content_reference_layer][0,:,:,40].eval()-layers[content_reference_layer][2,:,:,40].eval())
    plt.subplot(1,4,4)
    plt.imshow(layers[content_reference_layer][1,:,:,50].eval())
    plt.show()
    print(content_loss(layers[content_reference_layer][0,:,:,:].eval(), layers[content_reference_layer][2,:,:,:].eval()).eval())
# Out:
# 18214512.0

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    style_feature_layers = layers["block1_conv2"]
    print(style_loss(style_feature_layers[1,:,:,:], style_feature_layers[2,:,:,:]).eval())
# Out:
# 38302416.0

# %%
# Training
learning_rate = 1000

optimizer = tf.train.AdagradOptimizer(learning_rate)
gradients = optimizer.compute_gradients(loss, var_list=[combination_image])
train_step = optimizer.apply_gradients(gradients)
#train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, var_list=[combination_image])
n_iterations = 200
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    start_image = combination_image.eval()
    print(loss.eval())
    for i in range(n_iterations):
        #plt.figure(i)
        #plt.subplot(1,4,1)
        #plt.imshow(layers[content_reference_layer][0,:,:,40].eval())
        #plt.subplot(1,4,2)
        #plt.imshow(layers[content_reference_layer][2,:,:,40].eval())
        #plt.subplot(1,4,3)
        #plt.imshow(layers[content_reference_layer][0,:,:,40].eval()-layers[content_reference_layer][2,:,:,40].eval())
        #plt.subplot(1,4,4)
        #plt.imshow(layers[content_reference_layer][1,:,:,50].eval())
        #plt.show()
        sess.run(train_step)
        print("Error a la iteracion ", i, ": ", loss.eval())

    final_image = combination_image.eval()
    print(final_image)
# Out:
# 36365824.0
# Error a la iteracion  0 :  11092680000000.0
# Error a la iteracion  1 :  525936230000.0
# Error a la iteracion  2 :  105288450000.0
# Error a la iteracion  3 :  73616550000.0
# Error a la iteracion  4 :  24694055000.0
# Error a la iteracion  5 :  9991924000.0
# Error a la iteracion  6 :  6592792000.0
# Error a la iteracion  7 :  5034019000.0
# Error a la iteracion  8 :  4029404000.0
# Error a la iteracion  9 :  3312430000.0
# Error a la iteracion  10 :  2780358400.0
# Error a la iteracion  11 :  2373852700.0
# Error a la iteracion  12 :  2055503100.0
# Error a la iteracion  13 :  1801198800.0
# Error a la iteracion  14 :  1594592400.0
# Error a la iteracion  15 :  1424272500.0
# Error a la iteracion  16 :  1282060000.0
# Error a la iteracion  17 :  1161973800.0
# Error a la iteracion  18 :  1059551500.0
# Error a la iteracion  19 :  971407300.0
# Error a la iteracion  20 :  894939140.0
# Error a la iteracion  21 :  828117700.0
# Error a la iteracion  22 :  769339000.0
# Error a la iteracion  23 :  717323970.0
# Error a la iteracion  24 :  671042750.0
# Error a la iteracion  25 :  629655500.0
# Error a la iteracion  26 :  592474900.0
# Error a la iteracion  27 :  558930100.0
# Error a la iteracion  28 :  528546340.0
# Error a la iteracion  29 :  500926140.0
# Error a la iteracion  30 :  475732670.0
# Error a la iteracion  31 :  452679900.0
# Error a la iteracion  32 :  431523170.0
# Error a la iteracion  33 :  412052930.0
# Error a la iteracion  34 :  394088220.0
# Error a la iteracion  35 :  377472000.0
# Error a la iteracion  36 :  362067740.0
# Error a la iteracion  37 :  347756220.0
# Error a la iteracion  38 :  334432500.0
# Error a la iteracion  39 :  322004800.0
# Error a la iteracion  40 :  310390900.0
# Error a la iteracion  41 :  299519460.0
# Error a la iteracion  42 :  289325700.0
# Error a la iteracion  43 :  279752320.0
# Error a la iteracion  44 :  270748160.0
# Error a la iteracion  45 :  262267070.0
# Error a la iteracion  46 :  254268200.0
# Error a la iteracion  47 :  246713760.0
# Error a la iteracion  48 :  239570480.0
# Error a la iteracion  49 :  232807980.0
# Error a la iteracion  50 :  226398720.0
# Error a la iteracion  51 :  220317140.0
# Error a la iteracion  52 :  214540980.0
# Error a la iteracion  53 :  209048940.0
# Error a la iteracion  54 :  203822260.0
# Error a la iteracion  55 :  198843360.0
# Error a la iteracion  56 :  194096260.0
# Error a la iteracion  57 :  189566320.0
# Error a la iteracion  58 :  185239710.0
# Error a la iteracion  59 :  181104290.0
# Error a la iteracion  60 :  177148110.0
# Error a la iteracion  61 :  173361060.0
# Error a la iteracion  62 :  169732850.0
# Error a la iteracion  63 :  166254580.0
# Error a la iteracion  64 :  162917740.0
# Error a la iteracion  65 :  159714420.0
# Error a la iteracion  66 :  156637500.0
# Error a la iteracion  67 :  153679970.0
# Error a la iteracion  68 :  150835600.0
# Error a la iteracion  69 :  148098350.0
# Error a la iteracion  70 :  145462800.0
# Error a la iteracion  71 :  142923710.0
# Error a la iteracion  72 :  140476340.0
# Error a la iteracion  73 :  138115980.0
# Error a la iteracion  74 :  135838670.0
# Error a la iteracion  75 :  133640250.0
# Error a la iteracion  76 :  131516890.0
# Error a la iteracion  77 :  129465110.0
# Error a la iteracion  78 :  127481620.0
# Error a la iteracion  79 :  125563400.0
# Error a la iteracion  80 :  123707336.0
# Error a la iteracion  81 :  121910936.0
# Error a la iteracion  82 :  120171220.0
# Error a la iteracion  83 :  118485910.0
# Error a la iteracion  84 :  116852620.0
# Error a la iteracion  85 :  115269280.0
# Error a la iteracion  86 :  113733650.0
# Error a la iteracion  87 :  112243750.0
# Error a la iteracion  88 :  110797760.0
# Error a la iteracion  89 :  109393860.0
# Error a la iteracion  90 :  108030490.0
# Error a la iteracion  91 :  106705940.0
# Error a la iteracion  92 :  105418664.0
# Error a la iteracion  93 :  104167330.0
# Error a la iteracion  94 :  102950400.0
# Error a la iteracion  95 :  101766720.0
# Error a la iteracion  96 :  100615016.0
# Error a la iteracion  97 :  99494000.0
# Error a la iteracion  98 :  98402700.0
# Error a la iteracion  99 :  97339930.0
# Error a la iteracion  100 :  96304630.0
# Error a la iteracion  101 :  95295950.0
# Error a la iteracion  102 :  94312810.0
# Error a la iteracion  103 :  93354360.0
# Error a la iteracion  104 :  92419850.0
# Error a la iteracion  105 :  91508376.0
# Error a la iteracion  106 :  90619170.0
# Error a la iteracion  107 :  89751416.0
# Error a la iteracion  108 :  88904490.0
# Error a la iteracion  109 :  88077700.0
# Error a la iteracion  110 :  87270290.0
# Error a la iteracion  111 :  86481730.0
# Error a la iteracion  112 :  85711380.0
# Error a la iteracion  113 :  84958616.0
# Error a la iteracion  114 :  84223016.0
# Error a la iteracion  115 :  83503896.0
# Error a la iteracion  116 :  82800870.0
# Error a la iteracion  117 :  82113300.0
# Error a la iteracion  118 :  81440904.0
# Error a la iteracion  119 :  80783110.0
# Error a la iteracion  120 :  80139490.0
# Error a la iteracion  121 :  79509610.0
# Error a la iteracion  122 :  78893040.0
# Error a la iteracion  123 :  78289440.0
# Error a la iteracion  124 :  77698470.0
# Error a la iteracion  125 :  77119660.0
# Error a la iteracion  126 :  76552800.0
# Error a la iteracion  127 :  75997410.0
# Error a la iteracion  128 :  75453230.0
# Error a la iteracion  129 :  74920050.0
# Error a la iteracion  130 :  74397360.0
# Error a la iteracion  131 :  73885020.0
# Error a la iteracion  132 :  73382720.0
# Error a la iteracion  133 :  72890160.0
# Error a la iteracion  134 :  72407120.0
# Error a la iteracion  135 :  71933336.0
# Error a la iteracion  136 :  71468530.0
# Error a la iteracion  137 :  71012480.0
# Error a la iteracion  138 :  70564990.0
# Error a la iteracion  139 :  70125784.0
# Error a la iteracion  140 :  69694710.0
# Error a la iteracion  141 :  69271500.0
# Error a la iteracion  142 :  68855976.0
# Error a la iteracion  143 :  68448024.0
# Error a la iteracion  144 :  68047340.0
# Error a la iteracion  145 :  67653780.0
# Error a la iteracion  146 :  67267210.0
# Error a la iteracion  147 :  66887404.0
# Error a la iteracion  148 :  66514250.0
# Error a la iteracion  149 :  66147530.0
# Error a la iteracion  150 :  65787150.0
# Error a la iteracion  151 :  65432960.0
# Error a la iteracion  152 :  65084776.0
# Error a la iteracion  153 :  64742428.0
# Error a la iteracion  154 :  64405816.0
# Error a la iteracion  155 :  64074864.0
# Error a la iteracion  156 :  63749350.0
# Error a la iteracion  157 :  63429184.0
# Error a la iteracion  158 :  63114292.0
# Error a la iteracion  159 :  62804450.0
# Error a la iteracion  160 :  62499670.0
# Error a la iteracion  161 :  62199730.0
# Error a la iteracion  162 :  61904576.0
# Error a la iteracion  163 :  61614136.0
# Error a la iteracion  164 :  61328210.0
# Error a la iteracion  165 :  61046788.0
# Error a la iteracion  166 :  60769764.0
# Error a la iteracion  167 :  60496950.0
# Error a la iteracion  168 :  60228360.0
# Error a la iteracion  169 :  59963864.0
# Error a la iteracion  170 :  59703400.0
# Error a la iteracion  171 :  59446840.0
# Error a la iteracion  172 :  59194120.0
# Error a la iteracion  173 :  58945190.0
# Error a la iteracion  174 :  58699980.0
# Error a la iteracion  175 :  58458344.0
# Error a la iteracion  176 :  58220284.0
# Error a la iteracion  177 :  57985630.0
# Error a la iteracion  178 :  57754424.0
# Error a la iteracion  179 :  57526464.0
# Error a la iteracion  180 :  57301850.0
# Error a la iteracion  181 :  57080376.0
# Error a la iteracion  182 :  56862084.0
# Error a la iteracion  183 :  56646840.0
# Error a la iteracion  184 :  56434616.0
# Error a la iteracion  185 :  56225316.0
# Error a la iteracion  186 :  56018940.0
# Error a la iteracion  187 :  55815412.0
# Error a la iteracion  188 :  55614664.0
# Error a la iteracion  189 :  55416656.0
# Error a la iteracion  190 :  55221304.0
# Error a la iteracion  191 :  55028616.0
# Error a la iteracion  192 :  54838510.0
# Error a la iteracion  193 :  54650920.0
# Error a la iteracion  194 :  54465850.0
# Error a la iteracion  195 :  54283216.0
# Error a la iteracion  196 :  54102960.0
# Error a la iteracion  197 :  53925090.0
# Error a la iteracion  198 :  53749496.0
# Error a la iteracion  199 :  53576210.0
# [[[[ -38.746468   121.11986    -67.63923  ]
#    [ -44.55891    117.15069    -72.20006  ]
#    [ -54.16858    108.23463    -79.49856  ]
#    ...
#    [  10.668026   157.39441     33.69097  ]
#    [  10.752149   156.12315     38.629925 ]
#    [   8.734176   157.1524      39.528484 ]]
#
#   [[ -34.777378   112.513214   -62.39239  ]
#    [ -40.975666   109.67623    -66.71527  ]
#    [ -51.022125   101.380875   -73.962234 ]
#    ...
#    [  13.801136   148.27354     35.312305 ]
#    [  14.16518    148.46648     40.462933 ]
#    [  12.772639   152.17392     42.56484  ]]
#
#   [[ -32.657764    96.19163    -53.578175 ]
#    [ -37.995068    93.45325    -57.14628  ]
#    [ -46.212135    87.24959    -64.402214 ]
#    ...
#    [  18.83433    130.82257     35.406315 ]
#    [  20.564165   129.88698     40.417988 ]
#    [  20.644728   130.5858      43.863853 ]]
#
#   ...
#
#   [[ -52.000004    -9.635572   -26.906134 ]
#    [ -50.808056   -10.021503   -23.737837 ]
#    [ -45.901466   -10.251514   -18.332571 ]
#    ...
#    [-121.70494    -12.089632   -53.169125 ]
#    [-119.32359     -8.337875   -51.369865 ]
#    [-119.55403     -7.6748643  -51.841217 ]]
#
#   [[ -57.597046    -7.013092   -32.154568 ]
#    [ -56.93846     -9.1804285  -27.362066 ]
#    [ -51.719948   -11.475803   -20.795433 ]
#    ...
#    [-125.699295    -8.14757    -46.744278 ]
#    [-123.24081     -2.2443466  -44.428444 ]
#    [-123.42754      0.8763342  -41.986176 ]]
#
#   [[ -61.200584    -5.869889   -35.152756 ]
#    [ -61.205452    -9.056212   -29.249277 ]
#    [ -55.36267    -12.91988    -22.02294  ]
#    ...
#    [-127.52976     -7.7006836  -44.03792  ]
#    [-123.18597      0.9393583  -42.00147  ]
#    [  17.15493   -198.97029   -244.73373  ]]]]

# %%
final_image = final_image.reshape((image_size, image_size, 3))
final_image = final_image[:,:,::-1]
final_image[:,:,0] += red_mean
final_image[:,:,1] += green_mean
final_image[:,:,2] += blue_mean
final_image = np.clip(final_image, 0, 255).astype("uint8")
Image.fromarray(final_image)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1F4CBE37940>

# %%
print(final_image)
# Out:
# [[[ 36 237  84]
#   [ 31 233  79]
#   [ 24 225  69]
#   ...
#   [137 255 134]
#   [142 255 134]
#   [143 255 132]]
#
#  [[ 41 229  88]
#   [ 37 226  82]
#   [ 29 218  72]
#   ...
#   [139 255 137]
#   [144 255 137]
#   [146 255 136]]
#
#  [[ 50 212  91]
#   [ 46 210  85]
#   [ 39 204  77]
#   ...
#   [139 247 142]
#   [144 246 144]
#   [147 247 144]]
#
#  ...
#
#  [[ 77 107  71]
#   [ 80 106  72]
#   [ 85 106  77]
#   ...
#   [ 50 104   1]
#   [ 52 108   4]
#   [ 52 109   4]]
#
#  [[ 71 109  66]
#   [ 76 107  66]
#   [ 83 105  71]
#   ...
#   [ 57 108   0]
#   [ 59 114   0]
#   [ 61 117   0]]
#
#  [[ 68 110  62]
#   [ 74 107  62]
#   [ 81 103  68]
#   ...
#   [ 59 109   0]
#   [ 61 117   0]
#   [  0   0 140]]]
