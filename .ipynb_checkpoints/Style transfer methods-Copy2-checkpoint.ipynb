# %% [markdown]
# # Style transfer Methods, A review

# %% [markdown]
# ### A Neural Algorithm of Artistic Style
# Source: https://harishnarayanan.org/writing/artistic-style-transfer/
#
# Using VGG16 (or 19) and a gramm matrix to solve an optimization problem

# %%
# Imports
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
image_size = 128
images_path = "C:/Users/Acer/Documents/GitHub/style_transfer_2018"
# Load a content image
content_image = Image.open(images_path+"/content_images/006.jpg").resize((image_size, image_size))
style_image = Image.open(images_path+"/style_images/03.jpg").resize((image_size, image_size))
content_image.resize((128,128)) # Resize just to see it at a smaller size
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CE61AB9A90>

# %%
content_mat = np.array(content_image.convert('RGB'))
print(content_mat.shape)
#print(content_mat)
#print(content_mat.dtype)
style_image
# Out:
# (128, 128, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CE670111D0>

# %%
# Transforming into numeric information
content_array = np.asarray(content_image, dtype='float32')
content_array = np.expand_dims(content_array, axis=0)
style_array = np.asarray(style_image, dtype='float32')
style_array = np.expand_dims(style_array, axis=0)

red_mean = 103.939
green_mean = 116.779
blue_mean = 123.68

content_array[:,:,:,0] -= red_mean
content_array[:,:,:,1] -= green_mean
content_array[:,:,:,2] -= blue_mean
content_array = content_array[:,:,:,::-1]
style_array[:,:,:,0] -= red_mean
style_array[:,:,:,1] -= green_mean
style_array[:,:,:,2] -= blue_mean
style_array = style_array[:,:,:,::-1]

print(content_array.shape, style_array.shape)
# Out:
# (1, 128, 128, 3) (1, 128, 128, 3)

# %%
#Defining our loss functions
def content_loss(content, combination):
    return tf.reduce_sum(tf.square(content-combination))

def gram_matrix(x): # Hay que entenderla bien
    features = tf.keras.backend.batch_flatten(tf.keras.backend.permute_dimensions(x, (2, 0, 1)))
    gram = tf.matmul(features, tf.transpose(features))
    return gram

def style_loss(style, combination): # Tambien
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    return tf.reduce_sum(tf.square(S - C)) / (4. * (channels ** 2) * (image_size ** 4))

def total_variation_loss(x):
    a = tf.square(x[:, :image_size-1, :image_size-1, :] - x[:, 1:, :image_size-1, :])
    b = tf.square(x[:, :image_size-1, :image_size-1, :] - x[:, :image_size-1, 1:, :])
    return tf.reduce_sum(tf.pow(a + b, 1.25))

# %%
# Start creating the main graph
content_node = tf.constant(content_array, name = "content_image", dtype=tf.float32)
style_node = tf.constant(style_array, name = "style_image", dtype=tf.float32)
combination_image = tf.Variable(tf.random_uniform(shape=[1,image_size, image_size,3], minval = -1, maxval= 1), dtype=tf.float32)
input_ten = tf.concat([content_node, style_node, combination_image], axis = 0)

# %%
# Importing the VGG16 pre-trained net to use it on the content loss
vgg = tf.keras.applications.VGG16(include_top = False, weights = "imagenet", input_tensor = input_ten)

# %%
layers = dict([(layer.name, layer.output) for layer in vgg.layers])
layers
# Out:
# {'block1_conv1': <tf.Tensor 'block1_conv1/Relu:0' shape=(3, 128, 128, 64) dtype=float32>,
#  'block1_conv2': <tf.Tensor 'block1_conv2/Relu:0' shape=(3, 128, 128, 64) dtype=float32>,
#  'block1_pool': <tf.Tensor 'block1_pool/MaxPool:0' shape=(3, 64, 64, 64) dtype=float32>,
#  'block2_conv1': <tf.Tensor 'block2_conv1/Relu:0' shape=(3, 64, 64, 128) dtype=float32>,
#  'block2_conv2': <tf.Tensor 'block2_conv2/Relu:0' shape=(3, 64, 64, 128) dtype=float32>,
#  'block2_pool': <tf.Tensor 'block2_pool/MaxPool:0' shape=(3, 32, 32, 128) dtype=float32>,
#  'block3_conv1': <tf.Tensor 'block3_conv1/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_conv2': <tf.Tensor 'block3_conv2/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_conv3': <tf.Tensor 'block3_conv3/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_pool': <tf.Tensor 'block3_pool/MaxPool:0' shape=(3, 16, 16, 256) dtype=float32>,
#  'block4_conv1': <tf.Tensor 'block4_conv1/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_conv2': <tf.Tensor 'block4_conv2/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_conv3': <tf.Tensor 'block4_conv3/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_pool': <tf.Tensor 'block4_pool/MaxPool:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv1': <tf.Tensor 'block5_conv1/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv2': <tf.Tensor 'block5_conv2/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv3': <tf.Tensor 'block5_conv3/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_pool': <tf.Tensor 'block5_pool/MaxPool:0' shape=(3, 4, 4, 512) dtype=float32>,
#  'input_1': <tf.Tensor 'concat:0' shape=(3, 128, 128, 3) dtype=float32>}

# %%
# Continue with the graph
content_weight = 0.020
style_weight = 100
total_variation_weight = 2*(10**-5)

content_reference_layer = "block2_conv2"
style_reference_layers = ['block1_conv2', 'block2_conv2',
                  'block3_conv3', 'block4_conv3',
                  'block5_conv3']

loss = tf.Variable(0, name = "total_loss", dtype=tf.float32)

content_feature_layer = layers[content_reference_layer]
loss = loss + content_weight * content_loss(content_feature_layer[0,:,:,:], content_feature_layer[2,:,:,:])

for layer in style_reference_layers:
    style_feature_layers = layers[layer]
    #print(style_feature_layers)
    A = style_feature_layers [1, :, :, :] #Estilo
    B = style_feature_layers [2, :, :, :] #combinada
    loss = loss + style_loss(A, B)*style_weight/len(style_reference_layers)

loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    plt.subplot(1,4,1)
    plt.imshow(layers['block1_conv1'][0,:,:,50].eval()) #Contenido
    plt.subplot(1,4,2)
    plt.imshow(layers['block1_conv1'][1,:,:,50].eval()) 
    plt.subplot(1,4,3)
    plt.imshow(layers['block1_conv1'][2,:,:,50].eval())
    plt.subplot(1,4,4)
    plt.imshow(layers['block1_conv1'][0,:,:,50].eval()-layers['block1_conv1'][2,:,:,50].eval()) #Resta de las anteriores
    plt.show()
    print(content_loss((layers['block1_conv1'][0,:,:,:].eval()), (layers['block1_conv1'][2,:,:,:].eval())).eval())
# Out:
# 108187670.0

# %%
# implementing L-BFGS-B from scipy
def _loss(loss_evaled):
    print(loss_evaled)
    
optimizer = tf.contrib.opt.ScipyOptimizerInterface(loss, var_list = [combination_image], 
                                                   var_to_bounds={combination_image:(-150,200)}, method = "L-BFGS-B", options = {"maxiter":45})
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    optimizer.minimize(sess, loss_callback = _loss, fetches =[loss])
    final_image = combination_image.eval()
# Out:
# 28801932.0
# 28797800.0
# 28791868.0
# 28758580.0
# 28476264.0
# 25416712.0
# 25110468.0
# 23809190.0
# 22006162.0
# 19620408.0
# 16553432.0
# 13017820.0
# 9600977.0
# 8228109.5
# 5295520.0
# 7162022.0
# 3333978.5
# 2116774.5
# 709016.25
# 495051.5
# 338588.12
# 290480.66
# 249909.86
# 204619.98
# 181021.75
# 161187.53
# 142387.58
# 131139.69
# 123786.44
# 116009.45
# 113731.375
# 110380.09
# 109090.49
# 108088.875
# 104618.2
# 103193.96
# 101103.71
# 99882.36
# 98915.35
# 97672.79
# 96876.89
# 95675.34
# 95145.26
# 94282.77
# 93665.64
# 92733.086
# 93057.89
# 92403.734
# 92083.37
# 91464.64
# 90857.85
# 90618.87
# 90246.71
# 89860.16
# 89606.71
# 89217.38
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT'
#   Objective function value: 89217.382812
#   Number of iterations: 46
#   Number of functions evaluations: 56

# %%
final_image = final_image.reshape((image_size, image_size, 3))
final_image_b = final_image
final_image = final_image[:,:,::-1]
final_image[:,:,0] += red_mean
final_image[:,:,1] += green_mean
final_image[:,:,2] += blue_mean
final_image = np.clip(final_image, 0, 255).astype("uint8")
Image.fromarray(final_image)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CE6F786470>

# %%
# Training
   
learning_rate = 10
optimizer = tf.train.AdagradOptimizer(learning_rate)

gradients = optimizer.compute_gradients(loss, var_list=[combination_image])
train_step = optimizer.apply_gradients(gradients)

n_iterations = 500
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    start_image = combination_image.eval()
    print(loss.eval())
    for i in range(n_iterations):
        if i%50 == 0:
            plt.figure(i)
            plt.subplot(1,4,1)
            plt.imshow(layers[content_reference_layer][0,:,:,40].eval())
            plt.subplot(1,4,2)
            plt.imshow(layers[content_reference_layer][2,:,:,40].eval())
            plt.subplot(1,4,3)
            plt.imshow(layers[content_reference_layer][0,:,:,40].eval()-layers[content_reference_layer][2,:,:,40].eval())
            plt.subplot(1,4,4)
            plt.imshow(layers[content_reference_layer][1,:,:,50].eval())
            plt.show()
        sess.run(train_step)
        print("Error a la iteracion ", i, ": ", loss.eval())
        
    final_image = combination_image.eval()
    print(final_image)
# Out:
# 9376960.0
# Error a la iteracion  0 :  9246638.0
# Error a la iteracion  1 :  8763602.0
# Error a la iteracion  2 :  7872640.5
# Error a la iteracion  3 :  6793087.5
# Error a la iteracion  4 :  5772441.5
# Error a la iteracion  5 :  4952270.5
# Error a la iteracion  6 :  4358995.0
# Error a la iteracion  7 :  3942848.8
# Error a la iteracion  8 :  3636967.8
# Error a la iteracion  9 :  3393320.2
# Error a la iteracion  10 :  3186050.5
# Error a la iteracion  11 :  3002967.2
# Error a la iteracion  12 :  2837589.5
# Error a la iteracion  13 :  2685742.8
# Error a la iteracion  14 :  2545422.2
# Error a la iteracion  15 :  2414827.0
# Error a la iteracion  16 :  2292956.8
# Error a la iteracion  17 :  2178791.5
# Error a la iteracion  18 :  2071682.1
# Error a la iteracion  19 :  1971370.5
# Error a la iteracion  20 :  1877090.4
# Error a la iteracion  21 :  1788142.2
# Error a la iteracion  22 :  1704364.6
# Error a la iteracion  23 :  1625560.4
# Error a la iteracion  24 :  1551126.4
# Error a la iteracion  25 :  1480931.9
# Error a la iteracion  26 :  1414767.9
# Error a la iteracion  27 :  1352243.2
# Error a la iteracion  28 :  1293106.5
# Error a la iteracion  29 :  1237107.2
# Error a la iteracion  30 :  1184090.1
# Error a la iteracion  31 :  1133890.0
# Error a la iteracion  32 :  1086212.0
# Error a la iteracion  33 :  1040965.06
# Error a la iteracion  34 :  998036.5
# Error a la iteracion  35 :  957257.8
# Error a la iteracion  36 :  918621.5
# Error a la iteracion  37 :  881904.4
# Error a la iteracion  38 :  846987.6
# Error a la iteracion  39 :  813751.4
# Error a la iteracion  40 :  782094.44
# Error a la iteracion  41 :  751933.8
# Error a la iteracion  42 :  723134.1
# Error a la iteracion  43 :  695687.94
# Error a la iteracion  44 :  669503.7
# Error a la iteracion  45 :  644498.3
# Error a la iteracion  46 :  620656.5
# Error a la iteracion  47 :  597914.75
# Error a la iteracion  48 :  576237.6
# Error a la iteracion  49 :  555554.1
# Error a la iteracion  50 :  535817.25
# Error a la iteracion  51 :  516988.75
# Error a la iteracion  52 :  498995.94
# Error a la iteracion  53 :  481843.78
# Error a la iteracion  54 :  465471.16
# Error a la iteracion  55 :  449817.75
# Error a la iteracion  56 :  434887.6
# Error a la iteracion  57 :  420643.1
# Error a la iteracion  58 :  407036.4
# Error a la iteracion  59 :  394031.22
# Error a la iteracion  60 :  381643.78
# Error a la iteracion  61 :  369802.16
# Error a la iteracion  62 :  358483.0
# Error a la iteracion  63 :  347671.88
# Error a la iteracion  64 :  337347.62
# Error a la iteracion  65 :  327490.9
# Error a la iteracion  66 :  318082.62
# Error a la iteracion  67 :  309122.22
# Error a la iteracion  68 :  300567.2
# Error a la iteracion  69 :  292393.0
# Error a la iteracion  70 :  284588.4
# Error a la iteracion  71 :  277153.7
# Error a la iteracion  72 :  270067.38
# Error a la iteracion  73 :  263311.75
# Error a la iteracion  74 :  256864.38
# Error a la iteracion  75 :  250712.34
# Error a la iteracion  76 :  244839.55
# Error a la iteracion  77 :  239236.52
# Error a la iteracion  78 :  233876.98
# Error a la iteracion  79 :  228747.62
# Error a la iteracion  80 :  223848.58
# Error a la iteracion  81 :  219170.14
# Error a la iteracion  82 :  214697.86
# Error a la iteracion  83 :  210419.31
# Error a la iteracion  84 :  206322.06
# Error a la iteracion  85 :  202406.19
# Error a la iteracion  86 :  198662.22
# Error a la iteracion  87 :  195077.19
# Error a la iteracion  88 :  191645.7
# Error a la iteracion  89 :  188357.52
# Error a la iteracion  90 :  185207.23
# Error a la iteracion  91 :  182184.83
# Error a la iteracion  92 :  179285.69
# Error a la iteracion  93 :  176503.11
# Error a la iteracion  94 :  173827.56
# Error a la iteracion  95 :  171254.36
# Error a la iteracion  96 :  168779.77
# Error a la iteracion  97 :  166398.5
# Error a la iteracion  98 :  164104.98
# Error a la iteracion  99 :  161895.66
# Error a la iteracion  100 :  159768.39
# Error a la iteracion  101 :  157717.36
# Error a la iteracion  102 :  155741.38
# Error a la iteracion  103 :  153835.67
# Error a la iteracion  104 :  151996.33
# Error a la iteracion  105 :  150219.8
# Error a la iteracion  106 :  148502.12
# Error a la iteracion  107 :  146840.81
# Error a la iteracion  108 :  145234.44
# Error a la iteracion  109 :  143680.28
# Error a la iteracion  110 :  142175.16
# Error a la iteracion  111 :  140717.2
# Error a la iteracion  112 :  139302.16
# Error a la iteracion  113 :  137930.55
# Error a la iteracion  114 :  136599.55
# Error a la iteracion  115 :  135308.52
# Error a la iteracion  116 :  134054.89
# Error a la iteracion  117 :  132835.58
# Error a la iteracion  118 :  131650.28
# Error a la iteracion  119 :  130495.49
# Error a la iteracion  120 :  129370.984
# Error a la iteracion  121 :  128275.06
# Error a la iteracion  122 :  127207.164
# Error a la iteracion  123 :  126166.94
# Error a la iteracion  124 :  125151.91
# Error a la iteracion  125 :  124161.43
# Error a la iteracion  126 :  123194.2
# Error a la iteracion  127 :  122250.29
# Error a la iteracion  128 :  121328.414
# Error a la iteracion  129 :  120427.12
# Error a la iteracion  130 :  119547.41
# Error a la iteracion  131 :  118685.85
# Error a la iteracion  132 :  117843.12
# Error a la iteracion  133 :  117017.88
# Error a la iteracion  134 :  116211.27
# Error a la iteracion  135 :  115421.266
# Error a la iteracion  136 :  114647.35
# Error a la iteracion  137 :  113889.46
# Error a la iteracion  138 :  113147.17
# Error a la iteracion  139 :  112418.84
# Error a la iteracion  140 :  111703.72
# Error a la iteracion  141 :  111001.19
# Error a la iteracion  142 :  110311.5
# Error a la iteracion  143 :  109634.01
# Error a la iteracion  144 :  108968.59
# Error a la iteracion  145 :  108314.8
# Error a la iteracion  146 :  107672.92
# Error a la iteracion  147 :  107041.6
# Error a la iteracion  148 :  106421.71
# Error a la iteracion  149 :  105812.68
# Error a la iteracion  150 :  105214.71
# Error a la iteracion  151 :  104626.65
# Error a la iteracion  152 :  104047.87
# Error a la iteracion  153 :  103478.02
# Error a la iteracion  154 :  102916.76
# Error a la iteracion  155 :  102365.37
# Error a la iteracion  156 :  101822.414
# Error a la iteracion  157 :  101287.01
# Error a la iteracion  158 :  100759.86
# Error a la iteracion  159 :  100240.98
# Error a la iteracion  160 :  99729.66
# Error a la iteracion  161 :  99226.26
# Error a la iteracion  162 :  98730.125
# Error a la iteracion  163 :  98240.8
# Error a la iteracion  164 :  97759.43
# Error a la iteracion  165 :  97284.27
# Error a la iteracion  166 :  96816.305
# Error a la iteracion  167 :  96354.61
# Error a la iteracion  168 :  95898.78
# Error a la iteracion  169 :  95449.016
# Error a la iteracion  170 :  95005.234
# Error a la iteracion  171 :  94567.13
# Error a la iteracion  172 :  94134.71
# Error a la iteracion  173 :  93709.06
# Error a la iteracion  174 :  93288.74
# Error a la iteracion  175 :  92873.5
# Error a la iteracion  176 :  92463.88
# Error a la iteracion  177 :  92059.11
# Error a la iteracion  178 :  91659.19
# Error a la iteracion  179 :  91263.96
# Error a la iteracion  180 :  90874.24
# Error a la iteracion  181 :  90489.64
# Error a la iteracion  182 :  90110.04
# Error a la iteracion  183 :  89735.83
# Error a la iteracion  184 :  89365.83
# Error a la iteracion  185 :  89000.66
# Error a la iteracion  186 :  88640.39
# Error a la iteracion  187 :  88284.36
# Error a la iteracion  188 :  87933.24
# Error a la iteracion  189 :  87586.17
# Error a la iteracion  190 :  87244.05
# Error a la iteracion  191 :  86906.06
# Error a la iteracion  192 :  86571.77
# Error a la iteracion  193 :  86241.69
# Error a la iteracion  194 :  85915.04
# Error a la iteracion  195 :  85592.27
# Error a la iteracion  196 :  85272.85
# Error a la iteracion  197 :  84957.4
# Error a la iteracion  198 :  84646.04
# Error a la iteracion  199 :  84338.195
# Error a la iteracion  200 :  84033.766
# Error a la iteracion  201 :  83732.87
# Error a la iteracion  202 :  83435.516
# Error a la iteracion  203 :  83141.59
# Error a la iteracion  204 :  82851.23
# Error a la iteracion  205 :  82563.93
# Error a la iteracion  206 :  82279.6
# Error a la iteracion  207 :  81999.195
# Error a la iteracion  208 :  81721.805
# Error a la iteracion  209 :  81447.26
# Error a la iteracion  210 :  81176.336
# Error a la iteracion  211 :  80907.89
# Error a la iteracion  212 :  80642.67
# Error a la iteracion  213 :  80379.984
# Error a la iteracion  214 :  80120.26
# Error a la iteracion  215 :  79863.39
# Error a la iteracion  216 :  79609.17
# Error a la iteracion  217 :  79357.914
# Error a la iteracion  218 :  79109.586
# Error a la iteracion  219 :  78863.93
# Error a la iteracion  220 :  78620.484
# Error a la iteracion  221 :  78379.95
# Error a la iteracion  222 :  78141.84
# Error a la iteracion  223 :  77906.03
# Error a la iteracion  224 :  77672.22
# Error a la iteracion  225 :  77441.23
# Error a la iteracion  226 :  77212.58
# Error a la iteracion  227 :  76985.73
# Error a la iteracion  228 :  76761.42
# Error a la iteracion  229 :  76539.43
# Error a la iteracion  230 :  76319.945
# Error a la iteracion  231 :  76102.14
# Error a la iteracion  232 :  75887.01
# Error a la iteracion  233 :  75674.63
# Error a la iteracion  234 :  75464.03
# Error a la iteracion  235 :  75255.64
# Error a la iteracion  236 :  75049.625
# Error a la iteracion  237 :  74845.625
# Error a la iteracion  238 :  74643.7
# Error a la iteracion  239 :  74444.05
# Error a la iteracion  240 :  74246.38
# Error a la iteracion  241 :  74050.695
# Error a la iteracion  242 :  73857.02
# Error a la iteracion  243 :  73665.03
# Error a la iteracion  244 :  73475.46
# Error a la iteracion  245 :  73287.47
# Error a la iteracion  246 :  73101.41
# Error a la iteracion  247 :  72917.44
# Error a la iteracion  248 :  72735.016
# Error a la iteracion  249 :  72554.15
# Error a la iteracion  250 :  72375.25
# Error a la iteracion  251 :  72198.125
# Error a la iteracion  252 :  72022.85
# Error a la iteracion  253 :  71849.19
# Error a la iteracion  254 :  71677.56
# Error a la iteracion  255 :  71507.4
# Error a la iteracion  256 :  71338.91
# Error a la iteracion  257 :  71171.625
# Error a la iteracion  258 :  71006.08
# Error a la iteracion  259 :  70842.13
# Error a la iteracion  260 :  70679.695
# Error a la iteracion  261 :  70518.59
# Error a la iteracion  262 :  70359.266
# Error a la iteracion  263 :  70201.13
# Error a la iteracion  264 :  70044.336
# Error a la iteracion  265 :  69889.32
# Error a la iteracion  266 :  69735.73
# Error a la iteracion  267 :  69583.24
# Error a la iteracion  268 :  69432.39
# Error a la iteracion  269 :  69282.9
# Error a la iteracion  270 :  69134.516
# Error a la iteracion  271 :  68987.805
# Error a la iteracion  272 :  68842.375
# Error a la iteracion  273 :  68698.3
# Error a la iteracion  274 :  68555.56
# Error a la iteracion  275 :  68414.03
# Error a la iteracion  276 :  68273.58
# Error a la iteracion  277 :  68134.484
# Error a la iteracion  278 :  67996.8
# Error a la iteracion  279 :  67860.17
# Error a la iteracion  280 :  67724.695
# Error a la iteracion  281 :  67590.695
# Error a la iteracion  282 :  67457.19
# Error a la iteracion  283 :  67325.35
# Error a la iteracion  284 :  67194.3
# Error a la iteracion  285 :  67064.586
# Error a la iteracion  286 :  66935.945
# Error a la iteracion  287 :  66808.16
# Error a la iteracion  288 :  66681.664
# Error a la iteracion  289 :  66556.336
# Error a la iteracion  290 :  66432.07
# Error a la iteracion  291 :  66308.766
# Error a la iteracion  292 :  66186.555
# Error a la iteracion  293 :  66065.48
# Error a la iteracion  294 :  65944.89
# Error a la iteracion  295 :  65825.59
# Error a la iteracion  296 :  65707.32
# Error a la iteracion  297 :  65590.195
# Error a la iteracion  298 :  65473.895
# Error a la iteracion  299 :  65358.625
# Error a la iteracion  300 :  65244.074
# Error a la iteracion  301 :  65130.62
# Error a la iteracion  302 :  65017.97
# Error a la iteracion  303 :  64906.258
# Error a la iteracion  304 :  64795.152
# Error a la iteracion  305 :  64685.28
# Error a la iteracion  306 :  64576.434
# Error a la iteracion  307 :  64468.027
# Error a la iteracion  308 :  64360.797
# Error a la iteracion  309 :  64254.46
# Error a la iteracion  310 :  64148.65
# Error a la iteracion  311 :  64043.695
# Error a la iteracion  312 :  63939.785
# Error a la iteracion  313 :  63836.543
# Error a la iteracion  314 :  63733.824
# Error a la iteracion  315 :  63632.27
# Error a la iteracion  316 :  63531.547
# Error a la iteracion  317 :  63431.41
# Error a la iteracion  318 :  63331.973
# Error a la iteracion  319 :  63233.47
# Error a la iteracion  320 :  63135.62
# Error a la iteracion  321 :  63038.508
# Error a la iteracion  322 :  62941.953
# Error a la iteracion  323 :  62845.996
# Error a la iteracion  324 :  62751.01
# Error a la iteracion  325 :  62656.27
# Error a la iteracion  326 :  62562.402
# Error a la iteracion  327 :  62469.266
# Error a la iteracion  328 :  62376.836
# Error a la iteracion  329 :  62285.117
# Error a la iteracion  330 :  62193.777
# Error a la iteracion  331 :  62103.176
# Error a la iteracion  332 :  62013.145
# Error a la iteracion  333 :  61924.074
# Error a la iteracion  334 :  61835.176
# Error a la iteracion  335 :  61747.156
# Error a la iteracion  336 :  61659.793
# Error a la iteracion  337 :  61573.09
# Error a la iteracion  338 :  61486.93
# Error a la iteracion  339 :  61401.113
# Error a la iteracion  340 :  61315.88
# Error a la iteracion  341 :  61231.438
# Error a la iteracion  342 :  61147.69
# Error a la iteracion  343 :  61064.453
# Error a la iteracion  344 :  60981.617
# Error a la iteracion  345 :  60899.27
# Error a la iteracion  346 :  60817.438
# Error a la iteracion  347 :  60736.305
# Error a la iteracion  348 :  60655.656
# Error a la iteracion  349 :  60575.434
# Error a la iteracion  350 :  60496.125
# Error a la iteracion  351 :  60416.832
# Error a la iteracion  352 :  60338.28
# Error a la iteracion  353 :  60260.277
# Error a la iteracion  354 :  60182.688
# Error a la iteracion  355 :  60105.496
# Error a la iteracion  356 :  60029.023
# Error a la iteracion  357 :  59952.812
# Error a la iteracion  358 :  59877.188
# Error a la iteracion  359 :  59802.11
# Error a la iteracion  360 :  59727.29
# Error a la iteracion  361 :  59653.285
# Error a la iteracion  362 :  59579.445
# Error a la iteracion  363 :  59506.164
# Error a la iteracion  364 :  59433.203
# Error a la iteracion  365 :  59360.59
# Error a la iteracion  366 :  59288.523
# Error a la iteracion  367 :  59216.773
# Error a la iteracion  368 :  59145.703
# Error a la iteracion  369 :  59074.9
# Error a la iteracion  370 :  59004.5
# Error a la iteracion  371 :  58934.617
# Error a la iteracion  372 :  58864.98
# Error a la iteracion  373 :  58795.58
# Error a la iteracion  374 :  58726.918
# Error a la iteracion  375 :  58658.414
# Error a la iteracion  376 :  58590.37
# Error a la iteracion  377 :  58522.656
# Error a la iteracion  378 :  58455.266
# Error a la iteracion  379 :  58388.46
# Error a la iteracion  380 :  58322.074
# Error a la iteracion  381 :  58255.8
# Error a la iteracion  382 :  58190.21
# Error a la iteracion  383 :  58124.832
# Error a la iteracion  384 :  58059.83
# Error a la iteracion  385 :  57995.17
# Error a la iteracion  386 :  57930.902
# Error a la iteracion  387 :  57867.11
# Error a la iteracion  388 :  57803.22
# Error a la iteracion  389 :  57740.043
# Error a la iteracion  390 :  57677.09
# Error a la iteracion  391 :  57614.66
# Error a la iteracion  392 :  57552.26
# Error a la iteracion  393 :  57490.332
# Error a la iteracion  394 :  57428.88
# Error a la iteracion  395 :  57367.395
# Error a la iteracion  396 :  57306.758
# Error a la iteracion  397 :  57245.96
# Error a la iteracion  398 :  57185.812
# Error a la iteracion  399 :  57125.812
# Error a la iteracion  400 :  57066.22
# Error a la iteracion  401 :  57006.773
# Error a la iteracion  402 :  56947.402
# Error a la iteracion  403 :  56888.734
# Error a la iteracion  404 :  56830.285
# Error a la iteracion  405 :  56771.918
# Error a la iteracion  406 :  56714.098
# Error a la iteracion  407 :  56656.44
# Error a la iteracion  408 :  56598.766
# Error a la iteracion  409 :  56541.75
# Error a la iteracion  410 :  56484.99
# Error a la iteracion  411 :  56428.312
# Error a la iteracion  412 :  56372.082
# Error a la iteracion  413 :  56316.18
# Error a la iteracion  414 :  56260.383
# Error a la iteracion  415 :  56205.086
# Error a la iteracion  416 :  56149.99
# Error a la iteracion  417 :  56095.273
# Error a la iteracion  418 :  56040.62
# Error a la iteracion  419 :  55986.44
# Error a la iteracion  420 :  55932.258
# Error a la iteracion  421 :  55878.61
# Error a la iteracion  422 :  55825.152
# Error a la iteracion  423 :  55771.92
# Error a la iteracion  424 :  55719.004
# Error a la iteracion  425 :  55666.633
# Error a la iteracion  426 :  55614.02
# Error a la iteracion  427 :  55561.82
# Error a la iteracion  428 :  55509.92
# Error a la iteracion  429 :  55458.34
# Error a la iteracion  430 :  55406.914
# Error a la iteracion  431 :  55355.89
# Error a la iteracion  432 :  55304.94
# Error a la iteracion  433 :  55254.25
# Error a la iteracion  434 :  55203.773
# Error a la iteracion  435 :  55153.863
# Error a la iteracion  436 :  55103.664
# Error a la iteracion  437 :  55053.984
# Error a la iteracion  438 :  55004.406
# Error a la iteracion  439 :  54955.19
# Error a la iteracion  440 :  54906.027
# Error a la iteracion  441 :  54857.3
# Error a la iteracion  442 :  54808.656
# Error a la iteracion  443 :  54760.285
# Error a la iteracion  444 :  54712.164
# Error a la iteracion  445 :  54664.082
# Error a la iteracion  446 :  54616.465
# Error a la iteracion  447 :  54569.04
# Error a la iteracion  448 :  54521.88
# Error a la iteracion  449 :  54474.57
# Error a la iteracion  450 :  54427.97
# Error a la iteracion  451 :  54381.406
# Error a la iteracion  452 :  54335.15
# Error a la iteracion  453 :  54289.0
# Error a la iteracion  454 :  54242.953
# Error a la iteracion  455 :  54197.33
# Error a la iteracion  456 :  54151.938
# Error a la iteracion  457 :  54106.67
# Error a la iteracion  458 :  54061.54
# Error a la iteracion  459 :  54016.85
# Error a la iteracion  460 :  53972.062
# Error a la iteracion  461 :  53927.625
# Error a la iteracion  462 :  53883.277
# Error a la iteracion  463 :  53839.312
# Error a la iteracion  464 :  53795.387
# Error a la iteracion  465 :  53751.816
# Error a la iteracion  466 :  53708.234
# Error a la iteracion  467 :  53664.977
# Error a la iteracion  468 :  53621.812
# Error a la iteracion  469 :  53579.0
# Error a la iteracion  470 :  53536.348
# Error a la iteracion  471 :  53493.91
# Error a la iteracion  472 :  53451.355
# Error a la iteracion  473 :  53409.258
# Error a la iteracion  474 :  53367.312
# Error a la iteracion  475 :  53325.477
# Error a la iteracion  476 :  53283.84
# Error a la iteracion  477 :  53242.48
# Error a la iteracion  478 :  53201.152
# Error a la iteracion  479 :  53160.176
# Error a la iteracion  480 :  53119.168
# Error a la iteracion  481 :  53078.402
# Error a la iteracion  482 :  53037.688
# Error a la iteracion  483 :  52997.277
# Error a la iteracion  484 :  52957.035
# Error a la iteracion  485 :  52916.85
# Error a la iteracion  486 :  52876.89
# Error a la iteracion  487 :  52837.234
# Error a la iteracion  488 :  52797.668
# Error a la iteracion  489 :  52758.11
# Error a la iteracion  490 :  52718.98
# Error a la iteracion  491 :  52679.79
# Error a la iteracion  492 :  52641.086
# Error a la iteracion  493 :  52602.223
# Error a la iteracion  494 :  52563.65
# Error a la iteracion  495 :  52525.09
# Error a la iteracion  496 :  52486.914
# Error a la iteracion  497 :  52448.766
# Error a la iteracion  498 :  52410.86
# Error a la iteracion  499 :  52372.96
# [[[[ -36.421646    60.195057   107.010216 ]
#    [  -7.733122    81.0934     117.374146 ]
#    [ -13.622078    55.032055   140.042    ]
#    ...
#    [ -14.750676    27.927296   112.4135   ]
#    [  12.803428   -24.126554    91.348404 ]
#    [  42.550953   -50.329742    95.31917  ]]
#
#   [[ -14.944157    98.04153    127.88568  ]
#    [  24.112585    99.59483    131.159    ]
#    [  28.844984    96.08824    141.61288  ]
#    ...
#    [  -8.429599     3.6257904   90.499275 ]
#    [  -5.7004156   28.801449    38.98053  ]
#    [ -59.553017    68.69127     19.574007 ]]
#
#   [[ -56.733967    83.94698    143.18465  ]
#    [ -36.632977    60.42142    112.38693  ]
#    [ -15.78055     75.101814   128.67885  ]
#    ...
#    [  34.137253    -9.334208    62.160778 ]
#    [  32.310883    20.548483    14.612735 ]
#    [  65.48094     87.30539     31.404707 ]]
#
#   ...
#
#   [[-122.09953     61.142044    63.25406  ]
#    [ -70.060165    56.50771     66.98875  ]
#    [ -75.767105     9.66455     94.58251  ]
#    ...
#    [ -21.129026    26.849735    94.28965  ]
#    [  -2.1088896   22.537888    67.39167  ]
#    [  30.447147    40.717804    52.38022  ]]
#
#   [[-126.89673     -3.094521    48.448994 ]
#    [ -94.0378      16.672188    65.31069  ]
#    [ -89.00692     -1.5090666  103.1106   ]
#    ...
#    [ -53.68142    -13.817216    93.82023  ]
#    [ -22.747236    -4.1645184   71.75616  ]
#    [  18.09077     19.09321     27.48546  ]]
#
#   [[-120.65192    -58.619453    70.9097   ]
#    [ -90.05159    -28.065832    95.45386  ]
#    [ -72.5596     -47.916912   104.27713  ]
#    ...
#    [ -71.65859    -61.159412    91.85496  ]
#    [ -32.437847   -49.026424    70.17308  ]
#    [ -58.637592   -50.510193    68.61661  ]]]]

# %%
final_image = final_image_b[:,:,::-1]
final_image[:,:,0] += red_mean
final_image[:,:,1] += green_mean
final_image[:,:,2] += blue_mean
final_image = np.clip(final_image, 0, 255).astype("uint8")
Image.fromarray(final_image)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CE6F798320>
