# %% [markdown]
# # Style transfer Methods, A review

# %% [markdown]
# ### A Neural Algorithm of Artistic Style
# Source: https://harishnarayanan.org/writing/artistic-style-transfer/
#
# Using VGG16 (or 19) and a gramm matrix to solve an optimization problem

# %%
# Imports
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_size = 128
images_path = "C:/Users/Acer/Documents/GitHub/style_transfer_2018"
# Load a content image
content_image = Image.open(images_path+"/content_images/07.jpg").resize((image_size, image_size))
style_image = Image.open(images_path+"/style_images/02.jpg").resize((image_size, image_size))
content_image.resize((128,128)) # Resize just to see it at a smaller size
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x24BA9E76B38>

# %%
content_mat = np.array(content_image.convert('RGB'))
print(content_mat.shape)
#print(content_mat)
#print(content_mat.dtype)
content_image
# Out:
# (128, 128, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x24BAAFA2048>

# %%
# Transforming into numeric information
content_array = np.asarray(content_image, dtype='float32')
content_array = np.expand_dims(content_array, axis=0)
style_array = np.asarray(style_image, dtype='float32')
style_array = np.expand_dims(style_array, axis=0)

red_mean = 103.939
green_mean = 116.779
blue_mean = 123.68

content_array[:,:,:,0] -= red_mean
content_array[:,:,:,1] -= green_mean
content_array[:,:,:,2] -= blue_mean
content_array = content_array[:,:,:,::-1]
style_array[:,:,:,0] -= red_mean
style_array[:,:,:,1] -= green_mean
style_array[:,:,:,2] -= blue_mean
style_array = style_array[:,:,:,::-1]

print(content_array.shape, style_array.shape)
# Out:
# (1, 128, 128, 3) (1, 128, 128, 3)

# %%
#Defining our loss functions
def content_loss(content, combination):
    return tf.reduce_sum(tf.square(content-combination))

def gram_matrix(x): # Hay que entenderla bien
    features = tf.keras.backend.batch_flatten(tf.keras.backend.permute_dimensions(x, (2, 0, 1)))
    gram = tf.matmul(features, tf.transpose(features))
    return gram

def style_loss(style, combination): # Tambien
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    return tf.reduce_sum(tf.square(S - C)) / (4. * (channels ** 2) * (image_size ** 4))

def total_variation_loss(x):
    a = tf.square(x[:, :image_size-1, :image_size-1, :] - x[:, 1:, :image_size-1, :])
    b = tf.square(x[:, :image_size-1, :image_size-1, :] - x[:, :image_size-1, 1:, :])
    return tf.reduce_sum(tf.pow(a + b, 1.25))

# %%
# Start creating the main graph
content_node = tf.constant(content_array, name = "content_image", dtype=tf.float32)
style_node = tf.constant(style_array, name = "style_image", dtype=tf.float32)
combination_image = tf.Variable(tf.random_uniform(shape=[1,image_size, image_size,3], minval = -1, maxval= 1), dtype=tf.float32)
input_ten = tf.concat([content_node, style_node, combination_image], axis = 0)

# %%
# Importing the VGG16 pre-trained net to use it on the content loss
vgg = tf.keras.applications.VGG16(include_top = False, weights = "imagenet", input_tensor = input_ten)

# %%
layers = dict([(layer.name, layer.output) for layer in vgg.layers])
layers
# Out:
# {'block1_conv1': <tf.Tensor 'block1_conv1_4/Relu:0' shape=(3, 128, 128, 64) dtype=float32>,
#  'block1_conv2': <tf.Tensor 'block1_conv2_4/Relu:0' shape=(3, 128, 128, 64) dtype=float32>,
#  'block1_pool': <tf.Tensor 'block1_pool_4/MaxPool:0' shape=(3, 64, 64, 64) dtype=float32>,
#  'block2_conv1': <tf.Tensor 'block2_conv1_4/Relu:0' shape=(3, 64, 64, 128) dtype=float32>,
#  'block2_conv2': <tf.Tensor 'block2_conv2_4/Relu:0' shape=(3, 64, 64, 128) dtype=float32>,
#  'block2_pool': <tf.Tensor 'block2_pool_4/MaxPool:0' shape=(3, 32, 32, 128) dtype=float32>,
#  'block3_conv1': <tf.Tensor 'block3_conv1_4/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_conv2': <tf.Tensor 'block3_conv2_4/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_conv3': <tf.Tensor 'block3_conv3_4/Relu:0' shape=(3, 32, 32, 256) dtype=float32>,
#  'block3_pool': <tf.Tensor 'block3_pool_4/MaxPool:0' shape=(3, 16, 16, 256) dtype=float32>,
#  'block4_conv1': <tf.Tensor 'block4_conv1_4/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_conv2': <tf.Tensor 'block4_conv2_4/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_conv3': <tf.Tensor 'block4_conv3_4/Relu:0' shape=(3, 16, 16, 512) dtype=float32>,
#  'block4_pool': <tf.Tensor 'block4_pool_4/MaxPool:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv1': <tf.Tensor 'block5_conv1_4/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv2': <tf.Tensor 'block5_conv2_4/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_conv3': <tf.Tensor 'block5_conv3_4/Relu:0' shape=(3, 8, 8, 512) dtype=float32>,
#  'block5_pool': <tf.Tensor 'block5_pool_4/MaxPool:0' shape=(3, 4, 4, 512) dtype=float32>,
#  'input_5': <tf.Tensor 'concat_4:0' shape=(3, 128, 128, 3) dtype=float32>}

# %%
# Continue with the graph
content_weight = 0.005
style_weight = 20
total_variation_weight = 0.2*(10**-4)

content_reference_layer = "block2_conv2"
style_reference_layers = ['block1_conv2', 'block2_conv2',
                  'block3_conv3', 'block4_conv3',
                  'block5_conv3']

loss = tf.Variable(0, name = "total_loss", dtype=tf.float32)

content_feature_layer = layers[content_reference_layer]
loss = loss + content_weight * content_loss(content_feature_layer[0,:,:,:], content_feature_layer[2,:,:,:])

for layer in style_reference_layers:
    style_feature_layers = layers[layer]
    #print(style_feature_layers)
    A = style_feature_layers [1, :, :, :] #Estilo
    B = style_feature_layers [2, :, :, :] #combinada
    loss = loss + style_loss(A, B)*style_weight/len(style_reference_layers)

loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    plt.subplot(1,4,1)
    plt.imshow(layers['block1_conv1'][0,:,:,50].eval()) #Contenido
    plt.subplot(1,4,2)
    plt.imshow(layers['block1_conv1'][1,:,:,50].eval()) 
    plt.subplot(1,4,3)
    plt.imshow(layers['block1_conv1'][2,:,:,50].eval())
    plt.subplot(1,4,4)
    plt.imshow(layers['block1_conv1'][0,:,:,50].eval()-layers['block1_conv1'][2,:,:,50].eval()) #Resta de las anteriores
    plt.show()
    print(content_loss((layers['block1_conv1'][0,:,:,:].eval()), (layers['block1_conv1'][2,:,:,:].eval())).eval())

# %%
# implementing L-BFGS-B from scipy
def _loss(loss_evaled):
    print(loss_evaled)
    
optimizer = tf.contrib.opt.ScipyOptimizerInterface(loss, var_list = [combination_image], 
                                                   var_to_bounds={combination_image:(-150,200)}, method = "L-BFGS-B", options = {"maxiter":45})
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    optimizer.minimize(sess, loss_callback = _loss, fetches =[loss])
    final_image = combination_image.eval()

# %%
final_image = final_image.reshape((image_size, image_size, 3))
final_image = final_image[:,:,::-1]
final_image[:,:,0] += red_mean
final_image[:,:,1] += green_mean
final_image[:,:,2] += blue_mean
final_image = np.clip(final_image, 0, 255).astype("uint8")
Image.fromarray(final_image)

# %%
# Training
   
learning_rate = 10
optimizer = tf.train.AdagradOptimizer(learning_rate)

gradients = optimizer.compute_gradients(loss, var_list=[combination_image])
train_step = optimizer.apply_gradients(gradients)

n_iterations = 250
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    start_image = combination_image.eval()
    print(loss.eval())
    for i in range(n_iterations):
        if i%50 == 0:
            plt.figure(i)
            plt.subplot(1,4,1)
            plt.imshow(layers[content_reference_layer][0,:,:,40].eval())
            plt.subplot(1,4,2)
            plt.imshow(layers[content_reference_layer][2,:,:,40].eval())
            plt.subplot(1,4,3)
            plt.imshow(layers[content_reference_layer][0,:,:,40].eval()-layers[content_reference_layer][2,:,:,40].eval())
            plt.subplot(1,4,4)
            plt.imshow(layers[content_reference_layer][1,:,:,50].eval())
            plt.show()
        sess.run(train_step)
        print("Error a la iteracion ", i, ": ", loss.eval())
        
    final_image = combination_image.eval()
    print(final_image)
# Out:
# 3646720.0
# Error a la iteracion  0 :  3400200.2
# Error a la iteracion  1 :  3068470.8
# Error a la iteracion  2 :  2693567.2
# Error a la iteracion  3 :  2310135.5
# Error a la iteracion  4 :  1947973.9
# Error a la iteracion  5 :  1627842.4
# Error a la iteracion  6 :  1360383.8
# Error a la iteracion  7 :  1147889.6
# Error a la iteracion  8 :  986380.6
# Error a la iteracion  9 :  867938.2
# Error a la iteracion  10 :  783193.44
# Error a la iteracion  11 :  723053.4
# Error a la iteracion  12 :  679993.6
# Error a la iteracion  13 :  648305.1
# Error a la iteracion  14 :  624036.44
# Error a la iteracion  15 :  604617.2
# Error a la iteracion  16 :  588423.7
# Error a la iteracion  17 :  574415.56
# Error a la iteracion  18 :  561965.9
# Error a la iteracion  19 :  550662.9
# Error a la iteracion  20 :  540272.2
# Error a la iteracion  21 :  530640.6
# Error a la iteracion  22 :  521616.75
# Error a la iteracion  23 :  513107.62
# Error a la iteracion  24 :  505033.3
# Error a la iteracion  25 :  497333.25
# Error a la iteracion  26 :  489943.0
# Error a la iteracion  27 :  482843.25
# Error a la iteracion  28 :  475995.12
# Error a la iteracion  29 :  469380.22
# Error a la iteracion  30 :  462972.75
# Error a la iteracion  31 :  456755.62
# Error a la iteracion  32 :  450714.66
# Error a la iteracion  33 :  444823.8
# Error a la iteracion  34 :  439071.72
# Error a la iteracion  35 :  433452.16
# Error a la iteracion  36 :  427956.06
# Error a la iteracion  37 :  422572.75
# Error a la iteracion  38 :  417304.66
# Error a la iteracion  39 :  412134.03
# Error a la iteracion  40 :  407043.72
# Error a la iteracion  41 :  402043.38
# Error a la iteracion  42 :  397125.5
# Error a la iteracion  43 :  392291.62
# Error a la iteracion  44 :  387542.3
# Error a la iteracion  45 :  382869.44
# Error a la iteracion  46 :  378273.56
# Error a la iteracion  47 :  373760.8
# Error a la iteracion  48 :  369323.0
# Error a la iteracion  49 :  364960.88
# Error a la iteracion  50 :  360677.5
# Error a la iteracion  51 :  356466.66
# Error a la iteracion  52 :  352332.34
# Error a la iteracion  53 :  348284.06
# Error a la iteracion  54 :  344321.94
# Error a la iteracion  55 :  340432.1
# Error a la iteracion  56 :  336609.38
# Error a la iteracion  57 :  332863.94
# Error a la iteracion  58 :  329208.1
# Error a la iteracion  59 :  325643.0
# Error a la iteracion  60 :  322152.75
# Error a la iteracion  61 :  318735.3
# Error a la iteracion  62 :  315396.03
# Error a la iteracion  63 :  312123.12
# Error a la iteracion  64 :  308923.78
# Error a la iteracion  65 :  305798.66
# Error a la iteracion  66 :  302745.22
# Error a la iteracion  67 :  299761.22
# Error a la iteracion  68 :  296851.9
# Error a la iteracion  69 :  294019.66
# Error a la iteracion  70 :  291254.94
# Error a la iteracion  71 :  288554.7
# Error a la iteracion  72 :  285916.7
# Error a la iteracion  73 :  283340.03
# Error a la iteracion  74 :  280826.6
# Error a la iteracion  75 :  278374.22
# Error a la iteracion  76 :  275982.88
# Error a la iteracion  77 :  273655.44
# Error a la iteracion  78 :  271382.75
# Error a la iteracion  79 :  269166.88
# Error a la iteracion  80 :  267009.72
# Error a la iteracion  81 :  264907.84
# Error a la iteracion  82 :  262858.2
# Error a la iteracion  83 :  260860.19
# Error a la iteracion  84 :  258917.81
# Error a la iteracion  85 :  257025.39
# Error a la iteracion  86 :  255185.56
# Error a la iteracion  87 :  253392.42
# Error a la iteracion  88 :  251642.61
# Error a la iteracion  89 :  249932.89
# Error a la iteracion  90 :  248266.47
# Error a la iteracion  91 :  246643.55
# Error a la iteracion  92 :  245061.64
# Error a la iteracion  93 :  243519.19
# Error a la iteracion  94 :  242023.9
# Error a la iteracion  95 :  240564.16
# Error a la iteracion  96 :  239140.78
# Error a la iteracion  97 :  237754.23
# Error a la iteracion  98 :  236406.88
# Error a la iteracion  99 :  235090.05
# Error a la iteracion  100 :  233803.55
# Error a la iteracion  101 :  232546.11
# Error a la iteracion  102 :  231319.33
# Error a la iteracion  103 :  230119.44
# Error a la iteracion  104 :  228947.77
# Error a la iteracion  105 :  227804.56
# Error a la iteracion  106 :  226689.52
# Error a la iteracion  107 :  225603.22
# Error a la iteracion  108 :  224541.97
# Error a la iteracion  109 :  223504.62
# Error a la iteracion  110 :  222494.72
# Error a la iteracion  111 :  221504.9
# Error a la iteracion  112 :  220536.48
# Error a la iteracion  113 :  219588.42
# Error a la iteracion  114 :  218659.9
# Error a la iteracion  115 :  217753.1
# Error a la iteracion  116 :  216865.11
# Error a la iteracion  117 :  215998.12
# Error a la iteracion  118 :  215151.34
# Error a la iteracion  119 :  214323.27
# Error a la iteracion  120 :  213513.78
# Error a la iteracion  121 :  212721.92
# Error a la iteracion  122 :  211947.58
# Error a la iteracion  123 :  211188.23
# Error a la iteracion  124 :  210443.19
# Error a la iteracion  125 :  209713.08
# Error a la iteracion  126 :  208998.9
# Error a la iteracion  127 :  208297.38
# Error a la iteracion  128 :  207608.42
# Error a la iteracion  129 :  206934.77
# Error a la iteracion  130 :  206271.34
# Error a la iteracion  131 :  205621.44
# Error a la iteracion  132 :  204981.89
# Error a la iteracion  133 :  204354.36
# Error a la iteracion  134 :  203737.34
# Error a la iteracion  135 :  203131.6
# Error a la iteracion  136 :  202537.03
# Error a la iteracion  137 :  201954.12
# Error a la iteracion  138 :  201378.72
# Error a la iteracion  139 :  200813.16
# Error a la iteracion  140 :  200256.31
# Error a la iteracion  141 :  199709.94
# Error a la iteracion  142 :  199172.72
# Error a la iteracion  143 :  198645.72
# Error a la iteracion  144 :  198128.02
# Error a la iteracion  145 :  197619.31
# Error a la iteracion  146 :  197117.56
# Error a la iteracion  147 :  196624.83
# Error a la iteracion  148 :  196140.0
# Error a la iteracion  149 :  195660.72
# Error a la iteracion  150 :  195188.61
# Error a la iteracion  151 :  194723.78
# Error a la iteracion  152 :  194266.39
# Error a la iteracion  153 :  193813.0
# Error a la iteracion  154 :  193366.95
# Error a la iteracion  155 :  192929.73
# Error a la iteracion  156 :  192498.53
# Error a la iteracion  157 :  192074.78
# Error a la iteracion  158 :  191654.62
# Error a la iteracion  159 :  191240.67
# Error a la iteracion  160 :  190833.94
# Error a la iteracion  161 :  190430.81
# Error a la iteracion  162 :  190034.84
# Error a la iteracion  163 :  189641.75
# Error a la iteracion  164 :  189255.78
# Error a la iteracion  165 :  188875.7
# Error a la iteracion  166 :  188500.62
# Error a la iteracion  167 :  188132.14
# Error a la iteracion  168 :  187767.22
# Error a la iteracion  169 :  187407.7
# Error a la iteracion  170 :  187052.67
# Error a la iteracion  171 :  186701.19
# Error a la iteracion  172 :  186352.67
# Error a la iteracion  173 :  186008.83
# Error a la iteracion  174 :  185671.52
# Error a la iteracion  175 :  185336.75
# Error a la iteracion  176 :  185006.7
